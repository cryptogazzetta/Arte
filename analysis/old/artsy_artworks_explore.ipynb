# %%
import pandas as pd

# %%
artworks = pd.read_csv('../temporary-files/artsy_artworks_info.csv')
artworks
# Out:
#                         Title  \
# 0                Blood Orange
# 1                      Peachy
# 2                      Blinds
# 3         BEHIND LOCKED DOORS
# 4             Goodnight Helen
# ..                        ...
# 995              Reflection 2
# 996  Study for black brook IV
# 997             Trees at Dusk
# 998           Purple Split 12
# 999              Pink Petunia
#
#                                              Materials                 Price  \
# 0                                        Oil on canvas              US$6,300
# 1                                        Oil on canvas              US$6,700
# 2                              Oil on arches oil paper                US$850
# 3                            Oil and acrylic on canvas                €1,500
# 4                                         Oil on paper              US$1,675
# ..                                                 ...                   ...
# ...
