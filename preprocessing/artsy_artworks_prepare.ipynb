# %%
## IMPORTS

import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
# Models
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_absolute_error, median_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
## MODELS

def get_decision_tree(X_train, y_train):
    decision_tree = DecisionTreeRegressor(random_state=42)
    decision_tree.fit(X_train, y_train)
    return decision_tree

def get_linear_regression(X_train, y_train):
    linear_regression = LinearRegression()
    linear_regression.fit(X_train, y_train)
    return linear_regression

def get_random_forest(X_train, y_train):
    rf_model = RandomForestRegressor(random_state=1)
    rf_model.fit(X_train, y_train)
    return rf_model

def get_gradient_boosting(X_train, y_train):
    # get gradient boosting model
    gb_model = GradientBoostingRegressor(random_state=1)
    gb_model.fit(X_train, y_train)
    return gb_model

# gives a dataframe taking models as columns and score as rows
def get_all_models(x, y):
    x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)

    models = {'Linear regression': get_linear_regression(x_train, y_train),
              'Decision tree': get_decision_tree(x_train, y_train),
              'Random forest': get_random_forest(x_train, y_train),
              'Gradient boosting': get_gradient_boosting(x_train, y_train)}
    
    models_df = pd.DataFrame(columns=models.keys())
    for model_name, model in models.items():
        y_pred = model.predict(x_test)
        r2 = r2_score(y_test, y_pred)
        n = len(y_test)
        p = x_test.shape[1]
        adj_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)
        mean_error = mean_absolute_error(y_test, y_pred)
        median_error = median_absolute_error(y_test, y_pred)
        mape = mean_absolute_percentage_error(y_test, y_pred)
        mse = mean_squared_error(y_test, y_pred)
        pearson = np.corrcoef(y_test.to_numpy(), y_pred)[0, 1]

        models_df.loc['R² Score', model_name] = r2
        models_df.loc['Adjusted R² Score', model_name] = adj_r2
        models_df.loc['Pearson Correl Predicted-Actual', model_name] = pearson
        models_df.loc['Mean Absolute Error', model_name] = mean_error
        models_df.loc['Median Absolute Error', model_name] = median_error
        models_df.loc['Mean Squared Error', model_name] = mse

        # Round values
        models_df = models_df.round(2)

    return models_df, models

# %%
## INITIALIZING DATAFRAME

artworks = pd.read_csv('../temporary-files/artsy_artworks_info.csv')
# Out:
#                      Gallery     Scarcity  \
# 0                  Wallector  Unique work
# 1     Hashimoto Contemporary  Unique work
# 2           Dopeness Art Lab  Unique work
# 3       Tomio Koyama Gallery  Unique work
# 4           Allouard Gallery  Unique work
# ..                       ...          ...
# 895               Uprise Art  Unique work
# 896        Kyoto Art Gallery  Unique work
# 897  Walter Wickiser Gallery  Unique work
# 898          Gallery Delaive  Unique work
# 899            Nüart Gallery  Unique work
#
#                                                    URL             Artist  \
# 0    https://www.artsy.net/artwork/unknown-artist-p...     Unknown Artist
# 1    https://www.artsy.net/artwork/seonna-hong-verdant        Seonna Hong
# 2    https://www.artsy.net/artwork/jon-burgerman-ne...      Jon Burgerman
# 3    https://www.artsy.net/artwork/masahiko-kuwahar...  Masahiko Kuwahara
# 4    https://www.artsy.net/artwork/joanna-glazer-sunny      Joanna Glazer
# ..                                                 ...                ...
# 895  https://www.artsy.net/artwork/holly-addi-rue-b...         Holly Addi
# 896       https://www.artsy.net/artwork/unknown-act-57            Unknown
# 897  https://www.artsy.net/artwork/ralph-wickiser-h...     Ralph Wickiser
# 898  https://www.artsy.net/artwork/sam-francis-unti...        Sam Francis
# 899  https://www.artsy.net/artwork/kevin-tolman-gig...       Kevin Tolman
#
#                                        Materials                    Title  \
# 0                  A mixed colored oil on canvas  Portrait of Noble Woman
# 1                              Acrylic on canvas                  Verdant
# 2                              Aerosol on canvas                  Neoncat
# 3                              Acrylic on canvas                      Sky
# 4                              Acrylic on canvas                    Sunny
# ..                                           ...                      ...
# 895  Acrylic, charcoal, and watercolor on canvas       Rue Bonaparte No 2
# 896                                     Acrylics                   act-57
# 897                                 Oil on linen                   Heresy
# 898                             Acrylic on paper                 Untitled
# 899            Acrylic and mixed media on canvas    Gigue (For J.S. Bach)
#
#                  Price                                      Dimensions
# 0                 Sold  67 3/10 × 47 1/5 × 1 3/5 in | 171 × 120 × 4 cm
# 1                 Sold                       8 × 8 in | 20.3 × 20.3 cm
# 2                 Sold               29 9/10 × 29 9/10 in | 76 × 76 cm
# 3                 Sold             78 3/10 × 31 3/5 in | 199 × 80.3 cm
# 4               US$195       31 1/2 × 31 1/2 × 2/5 in | 80 × 80 × 1 cm
# ..                 ...                                             ...
# 895               Sold                    40 × 30 in | 101.6 × 76.2 cm
# 896             US$595                 15 3/5 × 12 in | 39.5 × 30.5 cm
# 897          US$20,000                     50 × 40 in | 127 × 101.6 cm
# 898  Contact for price                13 2/5 × 18 9/10 in | 34 × 48 cm
# 899           US$2,500           16 × 16 × 2 in | 40.6 × 40.6 × 5.1 cm
#
# [900 rows x 8 columns]

# %%
## CLEAN

# Remove rows without numbers in Price
artworks = artworks[artworks['Price'].str.contains(r'\d', na=False)]
artworks = artworks[artworks['Scarcity'] == 'Unique work']

# %%
## FIX PRICE

artworks['Currency'] = artworks['Price'].str.extract(r'(\D+)')

artworks['Price_fix'] = artworks['Price'].apply(lambda x: ''.join(re.findall(r'\d+', x)))
artworks['Price_fix'] = artworks['Price_fix'].astype(float)

currency_rates = {
    'US$': 1,
    '€': 1.18,
    '£': 1.38,
    'KRW ₩': 0.00089,
    'C$': 0.8,
    'AU$': 0.76
}

artworks['Price (US$)'] = artworks.apply(lambda x: x['Price_fix'] * currency_rates[x['Currency']], axis=1)

# %%
## FIX DIMENSIONS

artworks = artworks[artworks['Dimensions'].str.contains('×')]

artworks['Dimensions (cm)'] = artworks['Dimensions'].apply(lambda x: x.split('|')[1])
artworks['Height (cm)'] = artworks['Dimensions (cm)'].apply(lambda x: x.split('×')[0].strip())
artworks['Width (cm)'] = artworks['Dimensions (cm)'].apply(lambda x: x.split('×')[1].split('cm')[0].strip())
artworks['Size (cm²)'] = artworks['Height (cm)'].astype(float) * artworks['Width (cm)'].astype(float)

# %%
## DROP COLUMNS

artworks.drop(columns=['Dimensions (cm)', 'Dimensions', 'Height (cm)', 'Width (cm)', 'Price', 'Price_fix', 'Currency', 'Scarcity', 'URL', 'Title'], inplace=True)

# %%
## SPLIT MATERIALS INTO MEDIUMS AND MATERIALS

artworks['Materials'] = artworks['Materials'].apply(lambda x: x.lower())
artworks = artworks[artworks['Materials'].str.contains(' on ')]
# split materials into mediums and materials using 'on' as separator
artworks['Mediums'] = artworks['Materials'].apply(lambda x: x.split(' on ')[0])
artworks['Materials'] = artworks['Materials'].apply(lambda x: x.split(' on ')[1])

# %%
artworks
# Out:
#               Materials           Artist                   Gallery  \
# 0                canvas  Adrian Kay Wong                Uprise Art
# 1                canvas  Adrian Kay Wong                Uprise Art
# 2      arches oil paper  Adrian Kay Wong    Hashimoto Contemporary
# 3                canvas  Adrian Kay Wong        Galerie Tracanelli
# 4                 paper  Adrian Kay Wong                Uprise Art
# ...                 ...              ...                       ...
# 7548  die-cut rag paper     Damien Hirst  VINCE fine arts/ephemera
# 7549     handmade paper     Damien Hirst          TGB Contemporary
# 7550     handmade paper     Damien Hirst          New Art Editions
# 7553     handmade paper     Damien Hirst              Art Republic
# 7563              paper     Damien Hirst                   Kutlesa
#
#       Price (US$)  Size (cm²)  \
# 0          6300.0    10296.55
# 1          6700.0    10788.70
# 2           850.0      645.16
# 3          1770.0     5168.00
# 4          1675.0     3016.20
# ...           ...         ...
# 7548       7500.0     3234.00
# 7549      12420.0      600.00
# 7550      16815.0      600.00
# 7553      12406.2      620.00
# 7563       8000.0     3234.00
#
#                                                 Mediums
# 0                                                   oil
# 1                                                   oil
# 2                                                   oil
# 3                                       oil and acrylic
# 4                                                   oil
# ...                                                 ...
# 7548                                            acrylic
# 7549                              one shot enamel paint
# 7550                                       enamel paint
# 7553  enamel paint, watermark, microdot, hologam and...
# 7563                               acrylic and metallic
#
# [1901 rows x 6 columns]

# %%
# get dummies for materials, mediums, artist and gallery
dummies_df = pd.get_dummies(artworks, columns=['Materials', 'Mediums', 'Artist', 'Gallery'])

x = dummies_df.drop(['Price (US$)'], axis=1)
y = dummies_df['Price (US$)']

models_df, models = get_all_models(x, y)
models_df
# Out:
#                                                         Linear regression  \
# R² Score                                               -58808996642225.25
# Adjusted R² Score                                  -219954908701238.90625
# Pearson Correl Predicted-Actual                                 -0.007268
# Mean Absolute Error                                  596462293066916608.0
# Median Absolute Error                                       20599394138.0
# Mean Squared Error               13849641502353302757627967061838790656.0
#
#                                               Decision tree  \
# R² Score                                           0.125745
# Adjusted R² Score                                 -2.269851
# Pearson Correl Predicted-Actual                    0.919927
# Mean Absolute Error                      29553047142.928226
# Median Absolute Error                                 63.72
# Mean Squared Error               205888882729865420210176.0
#
#                                              Random forest  \
# R² Score                                          0.677122
# Adjusted R² Score                                -0.207613
# Pearson Correl Predicted-Actual                   0.998013
# Mean Absolute Error                     19351936927.375481
# Median Absolute Error                           189.515473
# Mean Squared Error               76038342990024933376000.0
#
#                                           Gradient boosting
# R² Score                                            0.12718
# Adjusted R² Score                                 -2.264484
# Pearson Correl Predicted-Actual                    0.963677
# Mean Absolute Error                      30172449695.232407
# Median Absolute Error                       30699815.616033
# Mean Squared Error               205550936112552390688768.0
