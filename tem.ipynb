# %%
import pandas as pd

df = pd.read_csv('./temporary-files/artsy_auctions_artworks_info.csv')

a = df[df['Artist_name'] == 'Marc Chagall']
a.drop_duplicates(subset=['url'], inplace=True)
a
# Out:
# /var/folders/rt/d94hn0nj1cl2kykjjkdpswxw0000gn/T/ipykernel_5595/1556148452.py:3: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./temporary-files/artsy_auctions_artworks_info.csv')
# /var/folders/rt/d94hn0nj1cl2kykjjkdpswxw0000gn/T/ipykernel_5595/1556148452.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.drop_duplicates(subset=['url'], inplace=True)
#                                                 url  Artist  \
# 1      https://www.artsy.net/auction-result/4955198     NaN
# 2      https://www.artsy.net/auction-result/7105707     NaN
# 3      https://www.artsy.net/auction-result/5668506     NaN
# 4      https://www.artsy.net/auction-result/1690220     NaN
# ...
